# %%
import numpy as np 
import pandas as pd 
import os
import time

# %%
import optuna
import optuna.logging

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier 
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
import nltk 
import spacy

# %% [markdown]
# Cоберем отзывы из обучающей и тестовой выборки в датафреймы:

# %%
neg_folder = '/kaggle/input/avaliacoes-de-filmes-dataset-imdb/aclImdb/train/neg'
pos_folder = '/kaggle/input/avaliacoes-de-filmes-dataset-imdb/aclImdb/train/pos'

test_neg = '/kaggle/input/avaliacoes-de-filmes-dataset-imdb/aclImdb/test/neg'
test_pos = '/kaggle/input/avaliacoes-de-filmes-dataset-imdb/aclImdb/test/pos'

# %%
data = []

# Обработка отрицательных отзывов
for filename in os.listdir(neg_folder):
    if filename.endswith('.txt'):
        id_rating = filename.split('.')[0] 
        id, rating = id_rating.split('_')    
        with open(os.path.join(neg_folder, filename), 'r', encoding='utf-8') as f:
            review = f.read()  # Читаем текст рецензии
        data.append([id, review, int(rating), 0])  # 0 для neg

# Обработка положительных отзывов
for filename in os.listdir(pos_folder):
    if filename.endswith('.txt'):
        id_rating = filename.split('.')[0]  
        id, rating = id_rating.split('_')    
        with open(os.path.join(pos_folder, filename), 'r', encoding='utf-8') as f:
            review = f.read()  # Читаем текст рецензии
        data.append([id, review, int(rating), 1])  # 1 для pos
        

df = pd.DataFrame(data, columns=['id', 'review', 'rating', 'status'])
df.to_csv('train.csv', index=False)

# %%
test_data = []

# Обработка отрицательных тестовых отзывов
for filename in os.listdir(test_neg):
    if filename.endswith('.txt'):
        id_rating = filename.split('.')[0]
        id, rating = id_rating.split('_')
        with open(os.path.join(test_neg, filename), 'r', encoding='utf-8') as f:
            review = f.read()  # Читаем текст рецензии
        test_data.append([id, review, int(rating), 0])  # 0 для neg

# Обработка положительных тестовых отзывов
for filename in os.listdir(test_pos):
    if filename.endswith('.txt'):
        id_rating = filename.split('.')[0]
        id, rating = id_rating.split('_')
        with open(os.path.join(test_pos, filename), 'r', encoding='utf-8') as f:
            review = f.read()  # Читаем текст рецензии
        test_data.append([id, review, int(rating), 1])  # 1 для pos

# Создаём DataFrame и сохраняем в CSV
test_df = pd.DataFrame(test_data, columns=['id', 'review', 'rating', 'status'])
test_df.to_csv('test.csv', index=False)

# %%
train_df = pd.read_csv('/kaggle/working/train.csv')
train_df.sample(7)
# Out:
#           id                                             review  rating  \
# 3686    5682  This movie is unbelievably ridiculous. I love ...       1
# 16226   7083  A great addition to anyone's collection.<br />...      10
# 3819    7536  I'd like to start off by saying that I am NOT ...       1
# 12439  10793  I saw this film at the 2005 Toronto Internatio...       4
# 964     4765  While the original titillates the intellect, t...       2
# 10883  11682  Now isn't it? Considering all the good work do...       1
# 13306    135  It was an excellent piece to the puppet series...       7
#
#        status
# 3686        0
# 16226       1
# 3819        0
# 12439       0
# 964         0
# 10883       0
# 13306       1

# %%
train_df = train_df.set_index('id')

train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 3606 to 8111
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  25000 non-null  object
#  1   rating  25000 non-null  int64
#  2   status  25000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 781.2+ KB

# %%
test_df = pd.read_csv('/kaggle/working/test.csv')
test_df = test_df.set_index('id')
test_df.sample(7)
# Out:
#                                                   review  rating  status
# id
# 11974  ... with a 500$ budget and a bottle of ketchup...       2       0
# 5809   Years ago, with "Ray of Light," Madonna broke ...      10       1
# 4962   I am a German student so sorry for eventually ...       4       0
# 9703   This movie is just about as good as the first ...       7       1
# 1714   This movie (even calling it a movie is an over...       1       0
# 1436   STAR RATING: ***** Saturday Night **** Friday ...       9       1
# 8811   There were so many things wrong with this movi...       1       0

# %%
train_df.describe()
# Out:
#              rating       status
# count  25000.000000  25000.00000
# mean       5.477720      0.50000
# std        3.466477      0.50001
# min        1.000000      0.00000
# 25%        2.000000      0.00000
# 50%        5.500000      0.50000
# 75%        9.000000      1.00000
# max       10.000000      1.00000

# %%
train_df.status.value_counts()
# Out:
# status
# 0    12500
# 1    12500
# Name: count, dtype: int64

# %% [markdown]
# Удалось обработать файлы. Переходим к подготовке данных.

# %% [markdown]
# ## Подготовка данных для обучения моделей

# %%
train_df['review']
# Out:
# id
# 3606     This film is the worst film, but it ranks very...
# 1074     I should never have started this film, and sto...
# 4743     I'm here again in your local shopping mall (of...
# 7628     Black and White film. Good photography. Believ...
# 6812     from the start of this movie you soon become a...
#                                ...
# 3156     Like the characters in this show, I too was a ...
# 4019     Being that I am not a fan of Snoop Dogg, as an...
# 12380    NYC model Alison Parker (Cristina Raines) rent...
# 6290     Using Buster Keaton in the twilight of his car...
# 8111     Things to Come is indeed a classic work of spe...
# Name: review, Length: 25000, dtype: object

# %%
X_train, X_val, y_train, y_val = train_test_split(train_df['review'], train_df['status'], 
                                                  test_size=0.2, random_state=42)

# Преобразование текста в числовые признаки с помощью TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)

# %% [markdown]
# ## LogReg

# %%
# optuna.logging.set_verbosity(optuna.logging.ERROR)

def objective(trial):
    C = trial.suggest_float('C', 1e-4, 1e2, log=True)
    solver = trial.suggest_categorical('solver', ['saga', 'lbfgs'])
    penalty = trial.suggest_categorical('penalty', ['l2', 'none'])  
    
    model = LogisticRegression(C=C, solver=solver, penalty=penalty, random_state=42)
    model.fit(X_train_tfidf, y_train)
    
    y_pred = model.predict(X_val_tfidf)
    
    return accuracy_score(y_val, y_pred)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20) 
print(f'Best trial: {study.best_trial.value}')
print(f'Best parameters: {study.best_trial.params}')

best_params = study.best_trial.params

# Обучение модели и замер времени
start_time = time.time()

model = LogisticRegression(**best_params)
model.fit(X_train_tfidf, y_train)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Время обучения модели: {elapsed_time:.4f} секунд")
# Оценка модели на валидационных данных
y_pred = model.predict(X_val_tfidf)
accuracy_logreg = accuracy_score(y_val, y_pred)
print(f'logreg Accuracy: {accuracy_logreg * 100:.2f}%')
# Out:
# [I 2024-10-12 15:13:38,845] A new study created in memory with name: no-name-2250eb0e-a30f-44eb-b439-af5f72c03847
# [I 2024-10-12 15:13:44,263] Trial 0 finished with value: 0.8502 and parameters: {'C': 0.011136217477152753, 'solver': 'saga', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:45,952] Trial 1 finished with value: 0.8346 and parameters: {'C': 0.09609208905204437, 'solver': 'lbfgs', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:46,112] Trial 2 finished with value: 0.8114 and parameters: {'C': 0.01789939540294499, 'solver': 'lbfgs', 'penalty': 'l2'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:47,784] Trial 3 finished with value: 0.8346 and parameters: {'C': 3.0175430816946793, 'solver': 'lbfgs', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:49,463] Trial 4 finished with value: 0.8346 and parameters: {'C': 8.341396333233982, 'solver': 'lbfgs', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:51,138] Trial 5 finished with value: 0.8346 and parameters: {'C': 1.881797518397828, 'solver': 'lbfgs', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:52,281] Trial 6 finished with value: 0.8186 and parameters: {'C': 0.025175695293035972, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:57,678] Trial 7 finished with value: 0.8502 and parameters: {'C': 0.0002816627591720846, 'solver': 'saga', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:13:58,996] Trial 8 finished with value: 0.666 and parameters: {'C': 0.00012187982107167765, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:14:00,670] Trial 9 finished with value: 0.8346 and parameters: {'C': 0.0022589042158498926, 'solver': 'lbfgs', 'penalty': 'none'}. Best is trial 0 with value: 0.8502.
# [I 2024-10-12 15:14:06,087] Trial 10 finished with value: 0.8576 and parameters: {'C': 94.76366420684315, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 10 with value: 0.8576.
# [I 2024-10-12 15:14:07,179] Trial 11 finished with value: 0.8762 and parameters: {'C': 0.5369320967160961, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 11 with value: 0.8762.
# [I 2024-10-12 15:14:12,605] Trial 12 finished with value: 0.8626 and parameters: {'C': 56.06721332604671, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 11 with value: 0.8762.
# [I 2024-10-12 15:14:18,035] Trial 13 finished with value: 0.8602 and parameters: {'C': 67.38741880107607, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 11 with value: 0.8762.
# [I 2024-10-12 15:14:19,142] Trial 14 finished with value: 0.8768 and parameters: {'C': 0.5538492641414322, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 14 with value: 0.8768.
# [I 2024-10-12 15:14:20,242] Trial 15 finished with value: 0.8752 and parameters: {'C': 0.4696231989174778, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 14 with value: 0.8768.
# [I 2024-10-12 15:14:21,343] Trial 16 finished with value: 0.8654 and parameters: {'C': 0.2329389303906682, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 14 with value: 0.8768.
# [I 2024-10-12 15:14:22,439] Trial 17 finished with value: 0.8824 and parameters: {'C': 0.9207920910663495, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 17 with value: 0.8824.
# [I 2024-10-12 15:14:24,931] Trial 18 finished with value: 0.8804 and parameters: {'C': 8.774675802156827, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 17 with value: 0.8824.
# [I 2024-10-12 15:14:27,500] Trial 19 finished with value: 0.8802 and parameters: {'C': 8.994536645781007, 'solver': 'saga', 'penalty': 'l2'}. Best is trial 17 with value: 0.8824.
# Best trial: 0.8824
# Best parameters: {'C': 0.9207920910663495, 'solver': 'saga', 'penalty': 'l2'}
# Время обучения модели: 1.0400 секунд
# Final logreg Accuracy: 88.24%

# %% [markdown]
# ## SGDClassifier

# %% [markdown]
# Ранее были найдены лучшие гиперпараметры, явно их задаю при инициализации.

# %%
clf = SGDClassifier(loss='hinge', penalty='l2', alpha=0.0001, fit_intercept=True, max_iter=1000, tol=0.001, shuffle=True, verbose=0, epsilon=0.1, n_jobs=None, random_state=42, learning_rate='optimal', eta0=0.0, power_t=0.5, early_stopping=False, validation_fraction=0.1, n_iter_no_change=5, class_weight=None, warm_start=False, average=False)

start_time = time.time()
clf.fit(X_train_tfidf, y_train)
end_time = time.time()
print(f'Время обучения модели: {end_time - start_time}')

y_pred = clf.predict(X_val_tfidf)

accuracy_sgdc = accuracy_score(y_val, y_pred)
print(f'sgdc Accuracy: {accuracy_sgdc * 100:.2f}%')
# Out:
# Время обучения модели: 0.23019957542419434
# sgdc Accuracy: 88.60%

# %% [markdown]
# ****SGDClassifier показывает лучшую точность на валидационной выборке и меньшее время обучения самой модели.****

# %% [markdown]
# Далее пробую нелинейные модели.

# %% [markdown]
# ## Multinomial Naive Bayes

# %% [markdown]
# Наивный Байес — это быстрая и простая модель, часто используемая для текстовой классификации, так как она работает хорошо с дискретными признаками, такими как частоты слов.

# %%
optuna.logging.set_verbosity(optuna.logging.ERROR)

def objective(trial):
    alpha = trial.suggest_float('alpha', 1e-4, 1.0, log=True)
    fit_prior = trial.suggest_categorical('fit_prior', [True, False])
    
    model = MultinomialNB(alpha=alpha, fit_prior=fit_prior)
    model.fit(X_train_tfidf, y_train)
    
    y_pred = model.predict(X_val_tfidf)
    
    return accuracy_score(y_val, y_pred)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20) 
print(f'Best trial: {study.best_trial.value}')
print(f'Best parameters: {study.best_trial.params}')

best_params = study.best_trial.params

# Обучение модели и замер времени
start_time = time.time()

model = MultinomialNB(**best_params)
model.fit(X_train_tfidf, y_train)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Время обучения модели: {elapsed_time:.4f} секунд")

# Оценка модели на валидационных данных
y_pred = model.predict(X_val_tfidf)
accuracy_nb = accuracy_score(y_val, y_pred)
print(f'MultinomialNB Accuracy: {accuracy_nb * 100:.2f}%')
# Out:
# Best trial: 0.8486
# Best parameters: {'alpha': 0.3702526824270394, 'fit_prior': False}
# Время обучения модели: 0.0226 секунд
# MultinomialNB Accuracy: 84.86%

# %% [markdown]
# Модель действительно оказалась в 10 раз быстрее, но менее точной на валидационных данных.

# %% [markdown]
# ## SVC
#
# SVM — это мощная модель для классификации, особенно если данные нелинейно разделимы. Она хорошо работает с высокоразмерными признаковыми пространствами, такими как текстовые данные.

# %%
def objective(trial):
    C = trial.suggest_loguniform('C', 1e-2, 1e1)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
    
    svm_model = SVC(kernel=kernel, C=C, random_state=42)
    svm_model.fit(X_train_tfidf, y_train)
    
    y_pred_svm = svm_model.predict(X_val_tfidf)
    return accuracy_score(y_val, y_pred_svm)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10)  # Увеличил до 10, чтобы собрать больше данных, но быстрее

print("Best parameters:", study.best_params)
print("Best accuracy svc:", study.best_value)
# Out:
# [I 2024-10-08 17:18:44,412] A new study created in memory with name: no-name-30b437b4-fb14-49bf-b0f6-94d560a93f5a
# [I 2024-10-08 17:27:21,368] Trial 0 finished with value: 0.8498 and parameters: {'C': 0.04190017106812743, 'kernel': 'linear'}. Best is trial 0 with value: 0.8498.
# [I 2024-10-08 17:35:13,306] Trial 1 finished with value: 0.8704 and parameters: {'C': 4.335002014165139, 'kernel': 'linear'}. Best is trial 1 with value: 0.8704.
# [I 2024-10-08 17:58:05,597] Trial 2 finished with value: 0.885 and parameters: {'C': 3.351868285046361, 'kernel': 'rbf'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:08:40,226] Trial 3 finished with value: 0.8132 and parameters: {'C': 0.017838097199152823, 'kernel': 'linear'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:14:51,532] Trial 4 finished with value: 0.8844 and parameters: {'C': 0.327478680673575, 'kernel': 'linear'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:24:22,632] Trial 5 finished with value: 0.88 and parameters: {'C': 0.4080753732488854, 'kernel': 'rbf'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:32:17,092] Trial 6 finished with value: 0.8662 and parameters: {'C': 0.07303518960041032, 'kernel': 'linear'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:40:39,483] Trial 7 finished with value: 0.8698 and parameters: {'C': 4.607711599028735, 'kernel': 'linear'}. Best is trial 2 with value: 0.885.
# [I 2024-10-08 18:48:47,275] Trial 8 finished with value: 0.863 and parameters: {'C': 0.0639893364362938, 'kernel': 'linear'}. Best is trial 2 with value: 0.885.

# %% [markdown]
# При долгом подборе гиперпараметров была достигнута та же точность, что и у SGDClassifier. Однако SVC обучается дольше, в езультате оптимальнее выбрать для бинарной классификации отзывов модель SGDClassifier.

# %% [markdown]
# ****Тест SGDClassifier****

# %%
from sklearn.metrics import classification_report

# %%
X_test_tfidf = tfidf_vectorizer.transform(test_df['review'])

y_test_pred = clf.predict(X_test_tfidf)

# %%
# Оценка точности модели на тестовом наборе
y_test_accuracy = accuracy_score(test_df['status'], y_test_pred)
print(f'Test set SGDC Accuracy: {y_test_accuracy * 100:.2f}%')
print(classification_report(test_df['status'], y_test_pred))
# Out:
# Test set SGDC Accuracy: 87.99%
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88     12500
#            1       0.88      0.89      0.88     12500
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.88     25000
# weighted avg       0.88      0.88      0.88     25000

# %% [markdown]
# ### Сохранение модели и векторизатора

# %%
   import joblib

# %%
   # Сохранение модели
   joblib.dump(clf, 'sgd_classifier_model.joblib')

   # Сохранение TF-IDF векторизатора
   joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.joblib')
# Out:
# ['tfidf_vectorizer.joblib']

# %% [markdown]
# # Модель предсказания рейтинга (многоклассовая классификация)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer

from catboost import CatBoostClassifier, Pool
from collections import Counter
import numpy as np
import joblib

# %% [markdown]
# Здесь весомая проблема дисбаланса классов и отсутствия нейтральных оценок.

# %%
train_df.rating.value_counts()
# Out:
# rating
# 1     5100
# 10    4732
# 8     3009
# 4     2696
# 7     2496
# 3     2420
# 2     2284
# 9     2263
# Name: count, dtype: int64

# %%
# Получаем частоты классов
class_counts = dict(Counter(train_df['rating']))

# Вычисляем веса как обратные пропорции частот классов
total_samples = len(train_df)
class_weights = {rating: total_samples / count for rating, count in class_counts.items()}

# Преобразуем в список весов для CatBoost
sorted_weights = [class_weights[i] for i in sorted(class_weights.keys())]

# %%
# Обучение модели
model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    class_weights=sorted_weights,
    text_features=['review'], 
    eval_metric='MultiClass',
)

model.fit(train_df[['review']], train_df['rating'])
# Out:
# 0:	learn: 1.9952692	total: 1.46s	remaining: 12m 9s
# 1:	learn: 1.9127988	total: 2.84s	remaining: 11m 47s
# 2:	learn: 1.8561137	total: 4.13s	remaining: 11m 23s
# 3:	learn: 1.8084333	total: 5.4s	remaining: 11m 9s
# 4:	learn: 1.7596127	total: 6.68s	remaining: 11m
# 5:	learn: 1.7217445	total: 7.97s	remaining: 10m 56s
# 6:	learn: 1.6831153	total: 9.37s	remaining: 10m 59s
# 7:	learn: 1.6426143	total: 10.8s	remaining: 11m 1s
# 8:	learn: 1.6118799	total: 12.2s	remaining: 11m 5s
# 9:	learn: 1.5864808	total: 13.6s	remaining: 11m 5s
# 10:	learn: 1.5652737	total: 15s	remaining: 11m 7s
# 11:	learn: 1.5447988	total: 16.4s	remaining: 11m 4s
# 12:	learn: 1.5259788	total: 17.8s	remaining: 11m 5s
# 13:	learn: 1.5129765	total: 19.1s	remaining: 11m 2s
# 14:	learn: 1.5002683	total: 20.4s	remaining: 10m 59s
# 15:	learn: 1.4911849	total: 21.7s	remaining: 10m 56s
# 16:	learn: 1.4809674	total: 23.4s	remaining: 11m 4s
# 17:	learn: 1.4695158	total: 24.7s	remaining: 11m 1s
# 18:	learn: 1.4576505	total: 26.1s	remaining: 11m 1s
# 19:	learn: 1.4531958	total: 27.4s	remaining: 10m 56s
# 20:	learn: 1.4465634	total: 28.6s	remaining: 10m 52s
# 21:	learn: 1.4378085	total: 29.9s	remaining: 10m 48s
# 22:	learn: 1.4332240	total: 31.2s	remaining: 10m 46s
# 23:	learn: 1.4268273	total: 32.5s	remaining: 10m 45s
# 24:	learn: 1.4220899	total: 33.8s	remaining: 10m 42s
# 25:	learn: 1.4146362	total: 35.1s	remaining: 10m 39s
# 26:	learn: 1.4118686	total: 36.4s	remaining: 10m 37s
# 27:	learn: 1.4096322	total: 37.7s	remaining: 10m 35s
# 28:	learn: 1.4092818	total: 38.9s	remaining: 10m 31s
# 29:	learn: 1.4081190	total: 40.1s	remaining: 10m 28s
# 30:	learn: 1.4065302	total: 41.4s	remaining: 10m 25s
# 31:	learn: 1.4054249	total: 42.6s	remaining: 10m 23s
# 32:	learn: 1.4006122	total: 43.9s	remaining: 10m 21s
# 33:	learn: 1.3992771	total: 45.2s	remaining: 10m 18s
# 34:	learn: 1.3977539	total: 46.4s	remaining: 10m 16s
# 35:	learn: 1.3959446	total: 47.7s	remaining: 10m 14s
# 36:	learn: 1.3941546	total: 48.9s	remaining: 10m 11s
# 37:	learn: 1.3925378	total: 50.2s	remaining: 10m 9s
# 38:	learn: 1.3913055	total: 51.4s	remaining: 10m 7s
# 39:	learn: 1.3873648	total: 52.7s	remaining: 10m 6s
# 40:	learn: 1.3865116	total: 53.9s	remaining: 10m 3s
# 41:	learn: 1.3855876	total: 55.4s	remaining: 10m 4s
# 42:	learn: 1.3839269	total: 56.8s	remaining: 10m 3s
# 43:	learn: 1.3830838	total: 58.1s	remaining: 10m 1s
# 44:	learn: 1.3820529	total: 59.3s	remaining: 9m 59s
# 45:	learn: 1.3807985	total: 1m	remaining: 9m 57s
# 46:	learn: 1.3786612	total: 1m 1s	remaining: 9m 55s
# 47:	learn: 1.3776101	total: 1m 3s	remaining: 9m 54s
# 48:	learn: 1.3771262	total: 1m 4s	remaining: 9m 51s
# 49:	learn: 1.3746272	total: 1m 5s	remaining: 9m 49s
# 50:	learn: 1.3743405	total: 1m 6s	remaining: 9m 47s
# 51:	learn: 1.3733152	total: 1m 7s	remaining: 9m 45s
# 52:	learn: 1.3729104	total: 1m 9s	remaining: 9m 42s
# 53:	learn: 1.3720702	total: 1m 10s	remaining: 9m 41s
# 54:	learn: 1.3717053	total: 1m 11s	remaining: 9m 39s
# 55:	learn: 1.3714144	total: 1m 12s	remaining: 9m 37s
# 56:	learn: 1.3708634	total: 1m 14s	remaining: 9m 35s
# 57:	learn: 1.3698092	total: 1m 15s	remaining: 9m 33s
# 58:	learn: 1.3684236	total: 1m 16s	remaining: 9m 31s
# 59:	learn: 1.3667735	total: 1m 17s	remaining: 9m 30s
# 60:	learn: 1.3655366	total: 1m 19s	remaining: 9m 28s
# 61:	learn: 1.3627419	total: 1m 20s	remaining: 9m 27s
# 62:	learn: 1.3616042	total: 1m 21s	remaining: 9m 26s
# 63:	learn: 1.3604964	total: 1m 22s	remaining: 9m 25s
# 64:	learn: 1.3597924	total: 1m 24s	remaining: 9m 23s
# 65:	learn: 1.3592112	total: 1m 25s	remaining: 9m 21s
# 66:	learn: 1.3574512	total: 1m 26s	remaining: 9m 20s
# 67:	learn: 1.3570083	total: 1m 28s	remaining: 9m 20s
# 68:	learn: 1.3565036	total: 1m 29s	remaining: 9m 19s
# 69:	learn: 1.3559179	total: 1m 30s	remaining: 9m 17s
# 70:	learn: 1.3551350	total: 1m 31s	remaining: 9m 15s
# 71:	learn: 1.3540742	total: 1m 33s	remaining: 9m 14s
# 72:	learn: 1.3535756	total: 1m 34s	remaining: 9m 12s
# 73:	learn: 1.3525186	total: 1m 35s	remaining: 9m 10s
# 74:	learn: 1.3518809	total: 1m 36s	remaining: 9m 9s
# 75:	learn: 1.3509831	total: 1m 38s	remaining: 9m 7s
# 76:	learn: 1.3504406	total: 1m 39s	remaining: 9m 6s
# 77:	learn: 1.3499988	total: 1m 40s	remaining: 9m 4s
# 78:	learn: 1.3490735	total: 1m 41s	remaining: 9m 3s
# 79:	learn: 1.3484821	total: 1m 43s	remaining: 9m 1s
# 80:	learn: 1.3479556	total: 1m 44s	remaining: 9m
# 81:	learn: 1.3464236	total: 1m 45s	remaining: 8m 58s
# 82:	learn: 1.3453238	total: 1m 47s	remaining: 8m 57s
# 83:	learn: 1.3446861	total: 1m 48s	remaining: 8m 55s
# 84:	learn: 1.3441513	total: 1m 49s	remaining: 8m 54s
# 85:	learn: 1.3434021	total: 1m 50s	remaining: 8m 52s
# 86:	learn: 1.3426486	total: 1m 51s	remaining: 8m 51s
# 87:	learn: 1.3418576	total: 1m 53s	remaining: 8m 49s
# 88:	learn: 1.3410157	total: 1m 54s	remaining: 8m 48s
# 89:	learn: 1.3406635	total: 1m 55s	remaining: 8m 46s
# 90:	learn: 1.3404685	total: 1m 56s	remaining: 8m 44s
# 91:	learn: 1.3401502	total: 1m 57s	remaining: 8m 43s
# 92:	learn: 1.3389780	total: 1m 59s	remaining: 8m 41s
# 93:	learn: 1.3381917	total: 2m	remaining: 8m 41s
# 94:	learn: 1.3335322	total: 2m 2s	remaining: 8m 41s
# 95:	learn: 1.3322367	total: 2m 3s	remaining: 8m 40s
# 96:	learn: 1.3313553	total: 2m 4s	remaining: 8m 38s
# 97:	learn: 1.3298662	total: 2m 6s	remaining: 8m 37s
# 98:	learn: 1.3247576	total: 2m 7s	remaining: 8m 36s
# 99:	learn: 1.3239524	total: 2m 8s	remaining: 8m 35s
# 100:	learn: 1.3219831	total: 2m 10s	remaining: 8m 34s
# 101:	learn: 1.3210438	total: 2m 11s	remaining: 8m 32s
# 102:	learn: 1.3202773	total: 2m 12s	remaining: 8m 31s
# 103:	learn: 1.3189369	total: 2m 13s	remaining: 8m 29s
# 104:	learn: 1.3179801	total: 2m 15s	remaining: 8m 28s
# 105:	learn: 1.3174945	total: 2m 16s	remaining: 8m 26s
# 106:	learn: 1.3131638	total: 2m 17s	remaining: 8m 25s
# 107:	learn: 1.3125070	total: 2m 18s	remaining: 8m 24s
# 108:	learn: 1.3086770	total: 2m 20s	remaining: 8m 23s
# 109:	learn: 1.3074758	total: 2m 21s	remaining: 8m 22s
# 110:	learn: 1.3065323	total: 2m 22s	remaining: 8m 20s
# 111:	learn: 1.3040204	total: 2m 24s	remaining: 8m 19s
# 112:	learn: 1.3025172	total: 2m 25s	remaining: 8m 18s
# 113:	learn: 1.3012126	total: 2m 26s	remaining: 8m 16s
# 114:	learn: 1.3000781	total: 2m 27s	remaining: 8m 15s
# 115:	learn: 1.2961747	total: 2m 29s	remaining: 8m 14s
# 116:	learn: 1.2949223	total: 2m 30s	remaining: 8m 13s
# 117:	learn: 1.2934010	total: 2m 31s	remaining: 8m 11s
# 118:	learn: 1.2904282	total: 2m 33s	remaining: 8m 12s
# 119:	learn: 1.2889791	total: 2m 35s	remaining: 8m 11s
# 120:	learn: 1.2873015	total: 2m 36s	remaining: 8m 10s
# 121:	learn: 1.2861790	total: 2m 37s	remaining: 8m 8s
# 122:	learn: 1.2834234	total: 2m 39s	remaining: 8m 7s
# 123:	learn: 1.2820796	total: 2m 40s	remaining: 8m 6s
# 124:	learn: 1.2794843	total: 2m 41s	remaining: 8m 5s
# 125:	learn: 1.2779390	total: 2m 43s	remaining: 8m 4s
# 126:	learn: 1.2752948	total: 2m 44s	remaining: 8m 3s
# 127:	learn: 1.2731119	total: 2m 45s	remaining: 8m 2s
# 128:	learn: 1.2714689	total: 2m 47s	remaining: 8m 1s
# 129:	learn: 1.2706078	total: 2m 48s	remaining: 7m 59s
# 130:	learn: 1.2693975	total: 2m 49s	remaining: 7m 58s
# 131:	learn: 1.2683760	total: 2m 51s	remaining: 7m 57s
# 132:	learn: 1.2667518	total: 2m 52s	remaining: 7m 56s
# 133:	learn: 1.2650678	total: 2m 53s	remaining: 7m 54s
# 134:	learn: 1.2634667	total: 2m 55s	remaining: 7m 53s
# 135:	learn: 1.2623150	total: 2m 56s	remaining: 7m 52s
# 136:	learn: 1.2610169	total: 2m 57s	remaining: 7m 51s
# 137:	learn: 1.2601760	total: 2m 59s	remaining: 7m 49s
# 138:	learn: 1.2590043	total: 3m	remaining: 7m 48s
# 139:	learn: 1.2574898	total: 3m 1s	remaining: 7m 47s
# 140:	learn: 1.2563760	total: 3m 3s	remaining: 7m 46s
# 141:	learn: 1.2553290	total: 3m 4s	remaining: 7m 45s
# 142:	learn: 1.2540684	total: 3m 6s	remaining: 7m 44s
# 143:	learn: 1.2531901	total: 3m 7s	remaining: 7m 43s
# 144:	learn: 1.2522021	total: 3m 8s	remaining: 7m 42s
# 145:	learn: 1.2512327	total: 3m 10s	remaining: 7m 41s
# 146:	learn: 1.2505002	total: 3m 11s	remaining: 7m 39s
# 147:	learn: 1.2494887	total: 3m 12s	remaining: 7m 38s
# 148:	learn: 1.2484628	total: 3m 14s	remaining: 7m 37s
# 149:	learn: 1.2471358	total: 3m 15s	remaining: 7m 36s
# 150:	learn: 1.2458653	total: 3m 16s	remaining: 7m 34s
# 151:	learn: 1.2448465	total: 3m 18s	remaining: 7m 33s
# 152:	learn: 1.2437467	total: 3m 19s	remaining: 7m 32s
# 153:	learn: 1.2426154	total: 3m 20s	remaining: 7m 31s
# 154:	learn: 1.2415020	total: 3m 22s	remaining: 7m 29s
# 155:	learn: 1.2409083	total: 3m 23s	remaining: 7m 28s
# 156:	learn: 1.2400053	total: 3m 24s	remaining: 7m 27s
# 157:	learn: 1.2388310	total: 3m 26s	remaining: 7m 26s
# 158:	learn: 1.2382725	total: 3m 27s	remaining: 7m 24s
# 159:	learn: 1.2373378	total: 3m 28s	remaining: 7m 23s
# 160:	learn: 1.2365964	total: 3m 29s	remaining: 7m 21s
# 161:	learn: 1.2356268	total: 3m 31s	remaining: 7m 20s
# 162:	learn: 1.2347202	total: 3m 32s	remaining: 7m 19s
# 163:	learn: 1.2339293	total: 3m 33s	remaining: 7m 18s
# 164:	learn: 1.2330600	total: 3m 35s	remaining: 7m 16s
# 165:	learn: 1.2323242	total: 3m 36s	remaining: 7m 15s
# 166:	learn: 1.2316592	total: 3m 38s	remaining: 7m 14s
# 167:	learn: 1.2305053	total: 3m 39s	remaining: 7m 14s
# 168:	learn: 1.2296313	total: 3m 41s	remaining: 7m 13s
# 169:	learn: 1.2288843	total: 3m 42s	remaining: 7m 11s
# 170:	learn: 1.2280539	total: 3m 43s	remaining: 7m 10s
# 171:	learn: 1.2273459	total: 3m 45s	remaining: 7m 9s
# 172:	learn: 1.2266004	total: 3m 46s	remaining: 7m 7s
# 173:	learn: 1.2256739	total: 3m 47s	remaining: 7m 6s
# 174:	learn: 1.2251240	total: 3m 48s	remaining: 7m 5s
# 175:	learn: 1.2243695	total: 3m 50s	remaining: 7m 3s
# 176:	learn: 1.2236955	total: 3m 51s	remaining: 7m 2s
# 177:	learn: 1.2229611	total: 3m 52s	remaining: 7m 1s
# 178:	learn: 1.2224700	total: 3m 54s	remaining: 6m 59s
# 179:	learn: 1.2218654	total: 3m 55s	remaining: 6m 58s
# 180:	learn: 1.2212489	total: 3m 56s	remaining: 6m 57s
# 181:	learn: 1.2202374	total: 3m 58s	remaining: 6m 55s
# 182:	learn: 1.2194511	total: 3m 59s	remaining: 6m 54s
# 183:	learn: 1.2187175	total: 4m	remaining: 6m 53s
# 184:	learn: 1.2178676	total: 4m 1s	remaining: 6m 51s
# 185:	learn: 1.2168843	total: 4m 3s	remaining: 6m 50s
# 186:	learn: 1.2159493	total: 4m 4s	remaining: 6m 49s
# 187:	learn: 1.2150684	total: 4m 6s	remaining: 6m 48s
# 188:	learn: 1.2141314	total: 4m 7s	remaining: 6m 47s
# 189:	learn: 1.2135378	total: 4m 8s	remaining: 6m 45s
# 190:	learn: 1.2129653	total: 4m 10s	remaining: 6m 44s
# 191:	learn: 1.2122248	total: 4m 11s	remaining: 6m 43s
# 192:	learn: 1.2115256	total: 4m 13s	remaining: 6m 42s
# 193:	learn: 1.2108935	total: 4m 14s	remaining: 6m 41s
# 194:	learn: 1.2100562	total: 4m 15s	remaining: 6m 40s
# 195:	learn: 1.2094891	total: 4m 16s	remaining: 6m 38s
# 196:	learn: 1.2085868	total: 4m 18s	remaining: 6m 37s
# 197:	learn: 1.2077380	total: 4m 19s	remaining: 6m 36s
# 198:	learn: 1.2065724	total: 4m 20s	remaining: 6m 34s
# 199:	learn: 1.2057011	total: 4m 22s	remaining: 6m 33s
# 200:	learn: 1.2050908	total: 4m 23s	remaining: 6m 32s
# 201:	learn: 1.2044625	total: 4m 25s	remaining: 6m 31s
# 202:	learn: 1.2038674	total: 4m 26s	remaining: 6m 29s
# 203:	learn: 1.2031922	total: 4m 27s	remaining: 6m 28s
# 204:	learn: 1.2022074	total: 4m 29s	remaining: 6m 27s
# 205:	learn: 1.2012540	total: 4m 30s	remaining: 6m 25s
# 206:	learn: 1.2004682	total: 4m 31s	remaining: 6m 24s
# 207:	learn: 1.1997248	total: 4m 33s	remaining: 6m 23s
# 208:	learn: 1.1990921	total: 4m 34s	remaining: 6m 22s
# 209:	learn: 1.1984548	total: 4m 35s	remaining: 6m 20s
# 210:	learn: 1.1978998	total: 4m 37s	remaining: 6m 19s
# 211:	learn: 1.1969141	total: 4m 38s	remaining: 6m 18s
# 212:	learn: 1.1962374	total: 4m 39s	remaining: 6m 16s
# 213:	learn: 1.1955841	total: 4m 41s	remaining: 6m 15s
# 214:	learn: 1.1949086	total: 4m 42s	remaining: 6m 14s
# 215:	learn: 1.1940406	total: 4m 44s	remaining: 6m 13s
# 216:	learn: 1.1935604	total: 4m 45s	remaining: 6m 12s
# 217:	learn: 1.1928612	total: 4m 46s	remaining: 6m 11s
# 218:	learn: 1.1922024	total: 4m 48s	remaining: 6m 9s
# 219:	learn: 1.1916122	total: 4m 49s	remaining: 6m 8s
# 220:	learn: 1.1910847	total: 4m 50s	remaining: 6m 7s
# 221:	learn: 1.1901053	total: 4m 52s	remaining: 6m 5s
# 222:	learn: 1.1895932	total: 4m 53s	remaining: 6m 4s
# 223:	learn: 1.1888026	total: 4m 54s	remaining: 6m 3s
# 224:	learn: 1.1881149	total: 4m 56s	remaining: 6m 2s
# 225:	learn: 1.1878388	total: 4m 57s	remaining: 6m
# 226:	learn: 1.1873171	total: 4m 58s	remaining: 5m 59s
# 227:	learn: 1.1867378	total: 4m 59s	remaining: 5m 57s
# 228:	learn: 1.1861235	total: 5m 1s	remaining: 5m 56s
# 229:	learn: 1.1854204	total: 5m 2s	remaining: 5m 55s
# 230:	learn: 1.1847871	total: 5m 3s	remaining: 5m 53s
# 231:	learn: 1.1841725	total: 5m 5s	remaining: 5m 52s
# 232:	learn: 1.1834970	total: 5m 6s	remaining: 5m 51s
# 233:	learn: 1.1829258	total: 5m 7s	remaining: 5m 50s
# 234:	learn: 1.1823299	total: 5m 9s	remaining: 5m 48s
# 235:	learn: 1.1817652	total: 5m 10s	remaining: 5m 47s
# 236:	learn: 1.1812916	total: 5m 11s	remaining: 5m 45s
# 237:	learn: 1.1804969	total: 5m 13s	remaining: 5m 44s
# 238:	learn: 1.1799785	total: 5m 14s	remaining: 5m 43s
# 239:	learn: 1.1794910	total: 5m 15s	remaining: 5m 42s
# 240:	learn: 1.1789127	total: 5m 17s	remaining: 5m 41s
# 241:	learn: 1.1784315	total: 5m 18s	remaining: 5m 39s
# 242:	learn: 1.1775749	total: 5m 20s	remaining: 5m 38s
# 243:	learn: 1.1771477	total: 5m 21s	remaining: 5m 37s
# 244:	learn: 1.1765073	total: 5m 22s	remaining: 5m 35s
# 245:	learn: 1.1758334	total: 5m 23s	remaining: 5m 34s
# 246:	learn: 1.1753836	total: 5m 25s	remaining: 5m 33s
# 247:	learn: 1.1744798	total: 5m 26s	remaining: 5m 31s
# 248:	learn: 1.1738696	total: 5m 27s	remaining: 5m 30s
# 249:	learn: 1.1730108	total: 5m 29s	remaining: 5m 29s
# 250:	learn: 1.1722685	total: 5m 30s	remaining: 5m 27s
# 251:	learn: 1.1717381	total: 5m 31s	remaining: 5m 26s
# 252:	learn: 1.1712534	total: 5m 33s	remaining: 5m 25s
# 253:	learn: 1.1708266	total: 5m 34s	remaining: 5m 23s
# 254:	learn: 1.1701774	total: 5m 35s	remaining: 5m 22s
# 255:	learn: 1.1697440	total: 5m 37s	remaining: 5m 21s
# 256:	learn: 1.1692531	total: 5m 38s	remaining: 5m 20s
# 257:	learn: 1.1683927	total: 5m 39s	remaining: 5m 18s
# 258:	learn: 1.1678026	total: 5m 41s	remaining: 5m 17s
# 259:	learn: 1.1674201	total: 5m 42s	remaining: 5m 16s
# 260:	learn: 1.1666140	total: 5m 43s	remaining: 5m 14s
# 261:	learn: 1.1657677	total: 5m 45s	remaining: 5m 13s
# 262:	learn: 1.1653937	total: 5m 46s	remaining: 5m 12s
# 263:	learn: 1.1647347	total: 5m 47s	remaining: 5m 10s
# 264:	learn: 1.1641538	total: 5m 49s	remaining: 5m 9s
# 265:	learn: 1.1634827	total: 5m 50s	remaining: 5m 8s
# 266:	learn: 1.1627170	total: 5m 51s	remaining: 5m 7s
# 267:	learn: 1.1619868	total: 5m 53s	remaining: 5m 5s
# 268:	learn: 1.1613603	total: 5m 54s	remaining: 5m 4s
# 269:	learn: 1.1607488	total: 5m 55s	remaining: 5m 3s
# 270:	learn: 1.1603470	total: 5m 57s	remaining: 5m 1s
# 271:	learn: 1.1599230	total: 5m 58s	remaining: 5m
# 272:	learn: 1.1594345	total: 5m 59s	remaining: 4m 59s
# 273:	learn: 1.1587115	total: 6m 1s	remaining: 4m 57s
# 274:	learn: 1.1582249	total: 6m 2s	remaining: 4m 56s
# 275:	learn: 1.1574585	total: 6m 3s	remaining: 4m 55s
# 276:	learn: 1.1568757	total: 6m 5s	remaining: 4m 53s
# 277:	learn: 1.1560484	total: 6m 6s	remaining: 4m 52s
# 278:	learn: 1.1555750	total: 6m 7s	remaining: 4m 51s
# 279:	learn: 1.1550473	total: 6m 9s	remaining: 4m 50s
# 280:	learn: 1.1543839	total: 6m 10s	remaining: 4m 48s
# 281:	learn: 1.1537767	total: 6m 11s	remaining: 4m 47s
# 282:	learn: 1.1533472	total: 6m 13s	remaining: 4m 46s
# 283:	learn: 1.1526119	total: 6m 14s	remaining: 4m 44s
# 284:	learn: 1.1518374	total: 6m 15s	remaining: 4m 43s
# 285:	learn: 1.1513586	total: 6m 17s	remaining: 4m 42s
# 286:	learn: 1.1508470	total: 6m 18s	remaining: 4m 40s
# 287:	learn: 1.1504530	total: 6m 19s	remaining: 4m 39s
# 288:	learn: 1.1499535	total: 6m 21s	remaining: 4m 38s
# 289:	learn: 1.1491797	total: 6m 22s	remaining: 4m 37s
# 290:	learn: 1.1486804	total: 6m 24s	remaining: 4m 35s
# 291:	learn: 1.1481148	total: 6m 25s	remaining: 4m 34s
# 292:	learn: 1.1474502	total: 6m 26s	remaining: 4m 33s
# 293:	learn: 1.1469022	total: 6m 28s	remaining: 4m 32s
# 294:	learn: 1.1465439	total: 6m 29s	remaining: 4m 30s
# 295:	learn: 1.1458859	total: 6m 30s	remaining: 4m 29s
# 296:	learn: 1.1454542	total: 6m 31s	remaining: 4m 27s
# 297:	learn: 1.1449438	total: 6m 33s	remaining: 4m 26s
# 298:	learn: 1.1445524	total: 6m 34s	remaining: 4m 25s
# 299:	learn: 1.1440104	total: 6m 35s	remaining: 4m 23s
# 300:	learn: 1.1433380	total: 6m 37s	remaining: 4m 22s
# 301:	learn: 1.1429111	total: 6m 38s	remaining: 4m 21s
# 302:	learn: 1.1421804	total: 6m 39s	remaining: 4m 19s
# 303:	learn: 1.1416074	total: 6m 41s	remaining: 4m 18s
# 304:	learn: 1.1409589	total: 6m 42s	remaining: 4m 17s
# 305:	learn: 1.1405416	total: 6m 43s	remaining: 4m 16s
# 306:	learn: 1.1401186	total: 6m 45s	remaining: 4m 14s
# 307:	learn: 1.1395873	total: 6m 46s	remaining: 4m 13s
# 308:	learn: 1.1390677	total: 6m 47s	remaining: 4m 12s
# 309:	learn: 1.1386241	total: 6m 49s	remaining: 4m 10s
# 310:	learn: 1.1382143	total: 6m 50s	remaining: 4m 9s
# 311:	learn: 1.1376673	total: 6m 51s	remaining: 4m 8s
# 312:	learn: 1.1370883	total: 6m 53s	remaining: 4m 6s
# 313:	learn: 1.1364435	total: 6m 54s	remaining: 4m 5s
# 314:	learn: 1.1358809	total: 6m 56s	remaining: 4m 4s
# 315:	learn: 1.1352305	total: 6m 57s	remaining: 4m 3s
# 316:	learn: 1.1347285	total: 6m 58s	remaining: 4m 1s
# 317:	learn: 1.1343628	total: 7m	remaining: 4m
# 318:	learn: 1.1337893	total: 7m 1s	remaining: 3m 59s
# 319:	learn: 1.1330490	total: 7m 2s	remaining: 3m 57s
# 320:	learn: 1.1326442	total: 7m 3s	remaining: 3m 56s
# 321:	learn: 1.1320103	total: 7m 5s	remaining: 3m 55s
# 322:	learn: 1.1315814	total: 7m 6s	remaining: 3m 53s
# 323:	learn: 1.1308312	total: 7m 7s	remaining: 3m 52s
# 324:	learn: 1.1303510	total: 7m 9s	remaining: 3m 51s
# 325:	learn: 1.1300398	total: 7m 10s	remaining: 3m 49s
# 326:	learn: 1.1294321	total: 7m 11s	remaining: 3m 48s
# 327:	learn: 1.1288485	total: 7m 12s	remaining: 3m 46s
# 328:	learn: 1.1284743	total: 7m 14s	remaining: 3m 45s
# 329:	learn: 1.1280066	total: 7m 15s	remaining: 3m 44s
# 330:	learn: 1.1273799	total: 7m 16s	remaining: 3m 42s
# 331:	learn: 1.1270714	total: 7m 17s	remaining: 3m 41s
# 332:	learn: 1.1263898	total: 7m 19s	remaining: 3m 40s
# 333:	learn: 1.1257246	total: 7m 20s	remaining: 3m 38s
# 334:	learn: 1.1252852	total: 7m 21s	remaining: 3m 37s
# 335:	learn: 1.1248462	total: 7m 23s	remaining: 3m 36s
# 336:	learn: 1.1243382	total: 7m 24s	remaining: 3m 34s
# 337:	learn: 1.1234267	total: 7m 25s	remaining: 3m 33s
# 338:	learn: 1.1228937	total: 7m 27s	remaining: 3m 32s
# 339:	learn: 1.1221087	total: 7m 28s	remaining: 3m 31s
# 340:	learn: 1.1216059	total: 7m 30s	remaining: 3m 29s
# 341:	learn: 1.1212936	total: 7m 31s	remaining: 3m 28s
# 342:	learn: 1.1203965	total: 7m 32s	remaining: 3m 27s
# 343:	learn: 1.1199865	total: 7m 34s	remaining: 3m 25s
# 344:	learn: 1.1194342	total: 7m 35s	remaining: 3m 24s
# 345:	learn: 1.1190148	total: 7m 36s	remaining: 3m 23s
# 346:	learn: 1.1185614	total: 7m 37s	remaining: 3m 21s
# 347:	learn: 1.1177994	total: 7m 39s	remaining: 3m 20s
# 348:	learn: 1.1171888	total: 7m 40s	remaining: 3m 19s
# 349:	learn: 1.1168558	total: 7m 41s	remaining: 3m 17s
# 350:	learn: 1.1163317	total: 7m 43s	remaining: 3m 16s
# 351:	learn: 1.1157254	total: 7m 44s	remaining: 3m 15s
# 352:	learn: 1.1152390	total: 7m 45s	remaining: 3m 14s
# 353:	learn: 1.1147686	total: 7m 47s	remaining: 3m 12s
# 354:	learn: 1.1140889	total: 7m 48s	remaining: 3m 11s
# 355:	learn: 1.1135123	total: 7m 49s	remaining: 3m 10s
# 356:	learn: 1.1130167	total: 7m 51s	remaining: 3m 8s
# 357:	learn: 1.1124522	total: 7m 52s	remaining: 3m 7s
# 358:	learn: 1.1119610	total: 7m 53s	remaining: 3m 6s
# 359:	learn: 1.1115046	total: 7m 54s	remaining: 3m 4s
# 360:	learn: 1.1109275	total: 7m 56s	remaining: 3m 3s
# 361:	learn: 1.1105390	total: 7m 57s	remaining: 3m 2s
# 362:	learn: 1.1100504	total: 7m 59s	remaining: 3m
# 363:	learn: 1.1091870	total: 8m	remaining: 2m 59s
# 364:	learn: 1.1086563	total: 8m 2s	remaining: 2m 58s
# 365:	learn: 1.1079765	total: 8m 3s	remaining: 2m 57s
# 366:	learn: 1.1074326	total: 8m 4s	remaining: 2m 55s
# 367:	learn: 1.1070350	total: 8m 6s	remaining: 2m 54s
# 368:	learn: 1.1065337	total: 8m 7s	remaining: 2m 53s
# 369:	learn: 1.1058930	total: 8m 8s	remaining: 2m 51s
# 370:	learn: 1.1054695	total: 8m 10s	remaining: 2m 50s
# 371:	learn: 1.1050429	total: 8m 11s	remaining: 2m 49s
# 372:	learn: 1.1046699	total: 8m 12s	remaining: 2m 47s
# 373:	learn: 1.1040552	total: 8m 13s	remaining: 2m 46s
# 374:	learn: 1.1035712	total: 8m 15s	remaining: 2m 45s
# 375:	learn: 1.1029787	total: 8m 16s	remaining: 2m 43s
# 376:	learn: 1.1024488	total: 8m 18s	remaining: 2m 42s
# 377:	learn: 1.1018384	total: 8m 19s	remaining: 2m 41s
# 378:	learn: 1.1014007	total: 8m 20s	remaining: 2m 39s
# 379:	learn: 1.1009907	total: 8m 22s	remaining: 2m 38s
# 380:	learn: 1.1006484	total: 8m 23s	remaining: 2m 37s
# 381:	learn: 1.1002393	total: 8m 24s	remaining: 2m 35s
# 382:	learn: 1.0995434	total: 8m 26s	remaining: 2m 34s
# 383:	learn: 1.0990546	total: 8m 27s	remaining: 2m 33s
# 384:	learn: 1.0986317	total: 8m 28s	remaining: 2m 31s
# 385:	learn: 1.0979765	total: 8m 30s	remaining: 2m 30s
# 386:	learn: 1.0974671	total: 8m 31s	remaining: 2m 29s
# 387:	learn: 1.0970640	total: 8m 33s	remaining: 2m 28s
# 388:	learn: 1.0965472	total: 8m 34s	remaining: 2m 26s
# 389:	learn: 1.0961179	total: 8m 36s	remaining: 2m 25s
# 390:	learn: 1.0956899	total: 8m 37s	remaining: 2m 24s
# 391:	learn: 1.0952747	total: 8m 38s	remaining: 2m 22s
# 392:	learn: 1.0945228	total: 8m 40s	remaining: 2m 21s
# 393:	learn: 1.0941263	total: 8m 41s	remaining: 2m 20s
# 394:	learn: 1.0938785	total: 8m 42s	remaining: 2m 18s
# 395:	learn: 1.0935658	total: 8m 43s	remaining: 2m 17s
# 396:	learn: 1.0931594	total: 8m 45s	remaining: 2m 16s
# 397:	learn: 1.0927048	total: 8m 46s	remaining: 2m 14s
# 398:	learn: 1.0923113	total: 8m 47s	remaining: 2m 13s
# 399:	learn: 1.0919893	total: 8m 48s	remaining: 2m 12s
# 400:	learn: 1.0915584	total: 8m 50s	remaining: 2m 10s
# 401:	learn: 1.0910883	total: 8m 51s	remaining: 2m 9s
# 402:	learn: 1.0906008	total: 8m 52s	remaining: 2m 8s
# 403:	learn: 1.0900711	total: 8m 54s	remaining: 2m 6s
# 404:	learn: 1.0896409	total: 8m 55s	remaining: 2m 5s
# 405:	learn: 1.0890909	total: 8m 56s	remaining: 2m 4s
# 406:	learn: 1.0885382	total: 8m 58s	remaining: 2m 2s
# 407:	learn: 1.0881182	total: 8m 59s	remaining: 2m 1s
# 408:	learn: 1.0876353	total: 9m	remaining: 2m
# 409:	learn: 1.0872405	total: 9m 2s	remaining: 1m 59s
# 410:	learn: 1.0866449	total: 9m 3s	remaining: 1m 57s
# 411:	learn: 1.0861608	total: 9m 4s	remaining: 1m 56s
# 412:	learn: 1.0857264	total: 9m 6s	remaining: 1m 55s
# 413:	learn: 1.0850010	total: 9m 7s	remaining: 1m 53s
# 414:	learn: 1.0846272	total: 9m 9s	remaining: 1m 52s
# 415:	learn: 1.0840845	total: 9m 10s	remaining: 1m 51s
# 416:	learn: 1.0837124	total: 9m 11s	remaining: 1m 49s
# 417:	learn: 1.0831847	total: 9m 12s	remaining: 1m 48s
# 418:	learn: 1.0827963	total: 9m 14s	remaining: 1m 47s
# 419:	learn: 1.0822727	total: 9m 15s	remaining: 1m 45s
# 420:	learn: 1.0816789	total: 9m 17s	remaining: 1m 44s
# 421:	learn: 1.0811833	total: 9m 18s	remaining: 1m 43s
# 422:	learn: 1.0806355	total: 9m 19s	remaining: 1m 41s
# 423:	learn: 1.0803138	total: 9m 21s	remaining: 1m 40s
# 424:	learn: 1.0797852	total: 9m 22s	remaining: 1m 39s
# 425:	learn: 1.0793856	total: 9m 23s	remaining: 1m 37s
# 426:	learn: 1.0788356	total: 9m 25s	remaining: 1m 36s
# 427:	learn: 1.0784459	total: 9m 26s	remaining: 1m 35s
# 428:	learn: 1.0779603	total: 9m 27s	remaining: 1m 33s
# 429:	learn: 1.0774359	total: 9m 28s	remaining: 1m 32s
# 430:	learn: 1.0770472	total: 9m 30s	remaining: 1m 31s
# 431:	learn: 1.0767207	total: 9m 31s	remaining: 1m 29s
# 432:	learn: 1.0763871	total: 9m 32s	remaining: 1m 28s
# 433:	learn: 1.0758766	total: 9m 34s	remaining: 1m 27s
# 434:	learn: 1.0754589	total: 9m 35s	remaining: 1m 25s
# 435:	learn: 1.0749410	total: 9m 36s	remaining: 1m 24s
# 436:	learn: 1.0744997	total: 9m 38s	remaining: 1m 23s
# 437:	learn: 1.0740413	total: 9m 39s	remaining: 1m 22s
# 438:	learn: 1.0735387	total: 9m 41s	remaining: 1m 20s
# 439:	learn: 1.0730058	total: 9m 42s	remaining: 1m 19s
# 440:	learn: 1.0725671	total: 9m 43s	remaining: 1m 18s
# 441:	learn: 1.0720678	total: 9m 45s	remaining: 1m 16s
# 442:	learn: 1.0715527	total: 9m 46s	remaining: 1m 15s
# 443:	learn: 1.0711682	total: 9m 47s	remaining: 1m 14s
# 444:	learn: 1.0707930	total: 9m 48s	remaining: 1m 12s
# 445:	learn: 1.0704508	total: 9m 50s	remaining: 1m 11s
# 446:	learn: 1.0699887	total: 9m 51s	remaining: 1m 10s
# 447:	learn: 1.0695299	total: 9m 52s	remaining: 1m 8s
# 448:	learn: 1.0690165	total: 9m 54s	remaining: 1m 7s
# 449:	learn: 1.0686969	total: 9m 55s	remaining: 1m 6s
# 450:	learn: 1.0682653	total: 9m 56s	remaining: 1m 4s
# 451:	learn: 1.0676779	total: 9m 58s	remaining: 1m 3s
# 452:	learn: 1.0671560	total: 9m 59s	remaining: 1m 2s
# 453:	learn: 1.0665996	total: 10m	remaining: 1m
# 454:	learn: 1.0662339	total: 10m 2s	remaining: 59.5s
# 455:	learn: 1.0656176	total: 10m 3s	remaining: 58.2s
# 456:	learn: 1.0651136	total: 10m 4s	remaining: 56.9s
# 457:	learn: 1.0645901	total: 10m 6s	remaining: 55.6s
# 458:	learn: 1.0640598	total: 10m 7s	remaining: 54.3s
# 459:	learn: 1.0633832	total: 10m 8s	remaining: 52.9s
# 460:	learn: 1.0629790	total: 10m 10s	remaining: 51.6s
# 461:	learn: 1.0624382	total: 10m 11s	remaining: 50.3s
# 462:	learn: 1.0620863	total: 10m 12s	remaining: 49s
# 463:	learn: 1.0617599	total: 10m 14s	remaining: 47.7s
# 464:	learn: 1.0613464	total: 10m 15s	remaining: 46.3s
# 465:	learn: 1.0607483	total: 10m 16s	remaining: 45s
# 466:	learn: 1.0603739	total: 10m 18s	remaining: 43.7s
# 467:	learn: 1.0598713	total: 10m 19s	remaining: 42.4s
# 468:	learn: 1.0593467	total: 10m 20s	remaining: 41s
# 469:	learn: 1.0588518	total: 10m 22s	remaining: 39.7s
# 470:	learn: 1.0584779	total: 10m 23s	remaining: 38.4s
# 471:	learn: 1.0580138	total: 10m 24s	remaining: 37.1s
# 472:	learn: 1.0576409	total: 10m 26s	remaining: 35.7s
# 473:	learn: 1.0571952	total: 10m 27s	remaining: 34.4s
# 474:	learn: 1.0567977	total: 10m 28s	remaining: 33.1s
# 475:	learn: 1.0563145	total: 10m 29s	remaining: 31.8s
# 476:	learn: 1.0558632	total: 10m 31s	remaining: 30.4s
# 477:	learn: 1.0554180	total: 10m 32s	remaining: 29.1s
# 478:	learn: 1.0549542	total: 10m 33s	remaining: 27.8s
# 479:	learn: 1.0546410	total: 10m 35s	remaining: 26.5s
# 480:	learn: 1.0540526	total: 10m 36s	remaining: 25.1s
# 481:	learn: 1.0535761	total: 10m 37s	remaining: 23.8s
# 482:	learn: 1.0530898	total: 10m 39s	remaining: 22.5s
# 483:	learn: 1.0526603	total: 10m 40s	remaining: 21.2s
# 484:	learn: 1.0523139	total: 10m 41s	remaining: 19.8s
# 485:	learn: 1.0516825	total: 10m 43s	remaining: 18.5s
# 486:	learn: 1.0512914	total: 10m 44s	remaining: 17.2s
# 487:	learn: 1.0509022	total: 10m 46s	remaining: 15.9s
# 488:	learn: 1.0505163	total: 10m 47s	remaining: 14.6s
# 489:	learn: 1.0501556	total: 10m 48s	remaining: 13.2s
# 490:	learn: 1.0496828	total: 10m 50s	remaining: 11.9s
# 491:	learn: 1.0492333	total: 10m 51s	remaining: 10.6s
# 492:	learn: 1.0488407	total: 10m 52s	remaining: 9.27s
# 493:	learn: 1.0483643	total: 10m 54s	remaining: 7.95s
# 494:	learn: 1.0480413	total: 10m 55s	remaining: 6.62s
# 495:	learn: 1.0477653	total: 10m 56s	remaining: 5.3s
# 496:	learn: 1.0472794	total: 10m 58s	remaining: 3.97s
# 497:	learn: 1.0469368	total: 10m 59s	remaining: 2.65s
# 498:	learn: 1.0462957	total: 11m	remaining: 1.32s
# 499:	learn: 1.0458488	total: 11m 2s	remaining: 0us

# %%
# Предсказание на тестовом наборе
y_pred = model.predict(test_df[['review']]) 

print(classification_report(test_df['rating'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.01      0.01      5022
#            2       0.62      0.00      0.01      2302
#            3       0.48      0.01      0.01      2541
#            4       0.29      0.00      0.00      2635
#            7       0.13      0.52      0.21      2307
#            8       0.20      0.25      0.23      2850
#            9       0.22      0.29      0.25      2344
#           10       0.34      0.62      0.44      4999
#
#     accuracy                           0.23     25000
#    macro avg       0.39      0.21      0.14     25000
# weighted avg       0.44      0.23      0.16     25000

# %% [markdown]
# ## Ансамблирование

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from imblearn.under_sampling import RandomUnderSampler

# Определяем модели с использованием GPU для CatBoost
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    eval_metric='MultiClass',
    task_type='GPU',  # Использование GPU
    silent=True
)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
lr_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Создаем pipeline для каждой модели
catboost_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('catboost', catboost_model)
])

rf_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('random_forest', rf_model)
])

lr_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('logistic_regression', lr_model)
])

# Создаем ансамбль
voting_clf = VotingClassifier(estimators=[
    ('catboost', catboost_pipeline),
    ('random_forest', rf_pipeline),
    ('logistic_regression', lr_pipeline)
], voting='soft')

# Создаем undersampler
undersampler = RandomUnderSampler(random_state=42)

# Применение undersampling к обучающему набору
X_resampled, y_resampled = undersampler.fit_resample(train_df[['review']], train_df['rating'])

# Обучение ансамбля на сбалансированном наборе
voting_clf.fit(X_resampled['review'], y_resampled)

# Предсказание на тестовом наборе
y_pred = voting_clf.predict(test_df['review'])

print(classification_report(test_df['rating'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.60      0.62      5022
#            2       0.22      0.25      0.23      2302
#            3       0.24      0.21      0.22      2541
#            4       0.31      0.32      0.32      2635
#            7       0.30      0.36      0.33      2307
#            8       0.27      0.21      0.24      2850
#            9       0.23      0.25      0.24      2344
#           10       0.55      0.56      0.55      4999
#
#     accuracy                           0.39     25000
#    macro avg       0.34      0.35      0.34     25000
# weighted avg       0.39      0.39      0.39     25000

# %%
import joblib

# Сохраняем ансамбль
joblib.dump(voting_clf, 'voting_classifier_model.joblib')

# Сохраняем TfidfVectorizer отдельно 
# joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer2.joblib')
# Out:
# ['voting_classifier_model.joblib']

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# Определяем модели с использованием GPU для CatBoost
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    eval_metric='MultiClass',
    task_type='GPU',  # Использование GPU
    silent=True
)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
lr_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Создаем pipeline для каждой модели
catboost_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('catboost', catboost_model)
])

rf_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('random_forest', rf_model)
])

lr_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('logistic_regression', lr_model)
])

# Создаем ансамбль
voting_clf = VotingClassifier(estimators=[
    ('catboost', catboost_pipeline),
    ('random_forest', rf_pipeline),
    ('logistic_regression', lr_pipeline)
], voting='soft')

# Создаем oversampler
oversampler = RandomOverSampler(random_state=42)

# Применение oversampling к обучающему набору
X_resampled, y_resampled = oversampler.fit_resample(train_df[['review']], train_df['rating'])

# Обучение ансамбля на увеличенном наборе данных
voting_clf.fit(X_resampled['review'], y_resampled)

# Предсказание на тестовом наборе
y_pred = voting_clf.predict(test_df['review'])

# Оценка производительности
print(classification_report(test_df['rating'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.73      0.64      5022
#            2       0.23      0.14      0.17      2302
#            3       0.27      0.18      0.22      2541
#            4       0.32      0.34      0.33      2635
#            7       0.29      0.29      0.29      2307
#            8       0.27      0.24      0.26      2850
#            9       0.24      0.14      0.17      2344
#           10       0.52      0.68      0.59      4999
#
#     accuracy                           0.42     25000
#    macro avg       0.34      0.34      0.33     25000
# weighted avg       0.38      0.42      0.39     25000

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report

# Определяем модели с использованием GPU для CatBoost
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    eval_metric='MultiClass',
    task_type='GPU',  # Использование GPU
    silent=True
)

# Упрощенная модель RandomForest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Создаем pipeline для каждой модели
catboost_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=5000)),
    ('catboost', catboost_model)
])

rf_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=5000)),
    ('random_forest', rf_model)
])

# Создаем ансамбль
voting_clf = VotingClassifier(estimators=[
    ('catboost', catboost_pipeline),
    ('random_forest', rf_pipeline)
], voting='soft')

# Обучение ансамбля без oversampling
voting_clf.fit(train_df['review'], train_df['rating'])

# Предсказание на тестовом наборе
y_pred = voting_clf.predict(test_df['review'])

# Оценка производительности
print(classification_report(test_df['rating'], y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 75
#      64 random_search = RandomizedSearchCV(
#      65     voting_clf,
#      66     param_distributions,
#    (...)
#      70     random_state=42
#      71 )
#      74 # Обучение модели с настройкой гиперпараметров
# ---> 75 random_search.fit(X_resampled['review'], y_resampled)
#      77 # Предсказание на тестовом наборе
#      78 y_pred = random_search.predict(test_df['review'])
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_voting.py:346, in VotingClassifier.fit(self, X, y, sample_weight)
#     343 self.classes_ = self.le_.classes_
#     344 transformed_y = self.le_.transform(y)
# --> 346 return super().fit(X, transformed_y, sample_weight)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_voting.py:81, in _BaseVoting.fit(self, X, y, sample_weight)
#      75 if self.weights is not None and len(self.weights) != len(self.estimators):
#      76     raise ValueError(
#      77         "Number of `estimators` and weights must be equal; got"
#      78         f" {len(self.weights)} weights, {len(self.estimators)} estimators"
#      79     )
# ---> 81 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      82     delayed(_fit_single_estimator)(
#      83         clone(clf),
#      84         X,
#      85         y,
#      86         sample_weight=sample_weight,
#      87         message_clsname="Voting",
#      88         message=self._log_message(names[idx], idx + 1, len(clfs)),
#      89     )
#      90     for idx, clf in enumerate(clfs)
#      91     if clf != "drop"
#      92 )
#      94 self.named_estimators_ = Bunch()
#      96 # Uses 'drop' as placeholder for dropped estimators
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_base.py:46, in _fit_single_estimator(estimator, X, y, sample_weight, message_clsname, message)
#      44 else:
#      45     with _print_elapsed_time(message_clsname, message):
# ---> 46         estimator.fit(X, y)
#      47 return estimator
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/pipeline.py:401, in Pipeline.fit(self, X, y, **fit_params)
#     375 """Fit the model.
#     376
#     377 Fit all the transformers one after the other and transform the
#    (...)
#     398     Pipeline with fitted steps.
#     399 """
#     400 fit_params_steps = self._check_fit_params(**fit_params)
# --> 401 Xt = self._fit(X, y, **fit_params_steps)
#     402 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403     if self._final_estimator != "passthrough":
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/pipeline.py:359, in Pipeline._fit(self, X, y, **fit_params_steps)
#     357     cloned_transformer = clone(transformer)
#     358 # Fit or load from cache the current transformer
# --> 359 X, fitted_transformer = fit_transform_one_cached(
#     360     cloned_transformer,
#     361     X,
#     362     y,
#     363     None,
#     364     message_clsname="Pipeline",
#     365     message=self._log_message(step_idx),
#     366     **fit_params_steps[name],
#     367 )
#     368 # Replace the transformer of the step with the fitted
#     369 # transformer. This is necessary when loading the transformer
#     370 # from the cache.
#     371 self.steps[step_idx] = (name, fitted_transformer)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/pipeline.py:893, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891 with _print_elapsed_time(message_clsname, message):
#     892     if hasattr(transformer, "fit_transform"):
# --> 893         res = transformer.fit_transform(X, y, **fit_params)
#     894     else:
#     895         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:2133, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2126 self._check_params()
#    2127 self._tfidf = TfidfTransformer(
#    2128     norm=self.norm,
#    2129     use_idf=self.use_idf,
#    2130     smooth_idf=self.smooth_idf,
#    2131     sublinear_tf=self.sublinear_tf,
#    2132 )
# -> 2133 X = super().fit_transform(raw_documents)
#    2134 self._tfidf.fit(X)
#    2135 # X is already a transformed view of raw_documents so
#    2136 # we set copy to False
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
#    1383                 " is True. These entries will not"
#    1384                 " be matched with any documents"
#    1385             )
#    1386             break
# -> 1388 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1390 if self.binary:
#    1391     X.data.fill(1)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1275, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1273 for doc in raw_documents:
#    1274     feature_counter = {}
# -> 1275     for feature in analyze(doc):
#    1276         try:
#    1277             feature_idx = vocabulary[feature]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:113, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     111     doc = preprocessor(doc)
#     112 if tokenizer is not None:
# --> 113     doc = tokenizer(doc)
#     114 if ngrams is not None:
#     115     if stop_words is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Стекинг

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from imblearn.under_sampling import RandomUnderSampler

# Определяем модели с использованием GPU для CatBoost
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    eval_metric='MultiClass',
    task_type='GPU',  # Использование GPU
    silent=True,
    thread_count=1
)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
lr_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Создаем pipeline для каждой модели
catboost_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('catboost', catboost_model)
])

rf_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('random_forest', rf_model)
])

lr_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('logistic_regression', lr_model)
])

stacking_clf = StackingClassifier(
    estimators=[
        ('catboost', catboost_pipeline),
        ('random_forest', rf_pipeline),
        ('logistic_regression', lr_pipeline)
    ],
    final_estimator=LogisticRegression(),
    cv=5,  # Кросс-валидация для устойчивости
    n_jobs=1  # Ограничиваем параллельные задачи
)

# Создаем undersampler
undersampler = RandomUnderSampler(random_state=42)

# Применение undersampling к обучающему набору
X_resampled, y_resampled = undersampler.fit_resample(train_df[['review']], train_df['rating'])

# Обучение ансамбля на сбалансированном наборе
stacking_clf.fit(X_resampled['review'], y_resampled)

# Предсказание на тестовом наборе
y_pred = stacking_clf.predict(test_df['review'])

# Оценка производительности
print(classification_report(test_df['rating'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.57      0.62      5022
#            2       0.22      0.27      0.25      2302
#            3       0.24      0.21      0.22      2541
#            4       0.30      0.40      0.34      2635
#            7       0.28      0.39      0.33      2307
#            8       0.27      0.19      0.23      2850
#            9       0.23      0.26      0.24      2344
#           10       0.59      0.53      0.56      4999
#
#     accuracy                           0.39     25000
#    macro avg       0.35      0.35      0.35     25000
# weighted avg       0.41      0.39      0.40     25000

# %% [markdown]
# UnderSampler не помог в качественном росте точности минорных классов. Лучше оказался OverSampling в VotingClassifier.

# %% [markdown]
# ## Sequential

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# Данные
X_train, X_test, y_train, y_test = train_test_split(train_df['review'], train_df['rating'], test_size=0.2, random_state=42)

# Применение TF-IDF векторизации
tfidf = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train).toarray()
X_test_tfidf = tfidf.transform(X_test).toarray()

# Создаем oversampler
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X_train_tfidf, y_train)

# Преобразуем метки от 1-4 и 7-10 в 0-7
y_resampled = y_resampled.apply(lambda x: x - 1 if x <= 4 else x - 3)
y_test = y_test.apply(lambda x: x - 1 if x <= 4 else x - 3)

# Преобразование данных в тензоры
X_resampled_tensor = torch.tensor(X_resampled, dtype=torch.float32)
y_resampled_tensor = torch.tensor(y_resampled.values, dtype=torch.long)
X_test_tensor = torch.tensor(X_test_tfidf, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long)

# Создание DataLoader для обучения
train_dataset = TensorDataset(X_resampled_tensor, y_resampled_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Параметры модели
input_size = X_resampled_tensor.shape[1]  # Количество признаков TF-IDF
output_size = 8  # Количество классов (оценки от 1 до 10, но без 5 и 6)

# Определение улучшенной модели
class ImprovedReviewClassifier(nn.Module):
    def __init__(self, input_size, output_size):
        super(ImprovedReviewClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 512),
            nn.ReLU(),
            nn.Dropout(0.3),  # Dropout для регуляризации
            nn.Linear(512, 256),
            nn.LeakyReLU(),
            nn.Linear(256, 128),
            nn.LeakyReLU(),
            nn.Linear(128, output_size)
        )
    
    def forward(self, x):
        return self.model(x)

# Инициализация модели
model = ImprovedReviewClassifier(input_size, output_size)

# Определение функции потерь и оптимизатора
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)  # L2-регуляризация (weight_decay)

# Тренировка модели
num_epochs = 20
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}")

# Оценка модели
model.eval()
with torch.no_grad():
    outputs = model(X_test_tensor)
    _, predictions = torch.max(outputs, 1)

# Вывод отчета по классификации
print(classification_report(y_test_tensor, predictions))
# Out:
# Epoch 1/20, Loss: 1.5386286430396212
# Epoch 2/20, Loss: 1.1524381666734027
# Epoch 3/20, Loss: 0.7181028331212568
# Epoch 4/20, Loss: 0.37502939121363915
# Epoch 5/20, Loss: 0.2070683382028703
# Epoch 6/20, Loss: 0.12488727609457452
# Epoch 7/20, Loss: 0.08813142536824055
# Epoch 8/20, Loss: 0.07378789157480906
# Epoch 9/20, Loss: 0.06456709115942776
# Epoch 10/20, Loss: 0.05243718680522884
# Epoch 11/20, Loss: 0.05078161393935608
# Epoch 12/20, Loss: 0.04370065226261513
# Epoch 13/20, Loss: 0.04167460285399634
# Epoch 14/20, Loss: 0.037786185886203305
# Epoch 15/20, Loss: 0.0410004809038935
# Epoch 16/20, Loss: 0.03723338383469556
# Epoch 17/20, Loss: 0.03654667219455097
# Epoch 18/20, Loss: 0.03642187906311162
# Epoch 19/20, Loss: 0.03424999376072288
# Epoch 20/20, Loss: 0.03174746874104748
#               precision    recall  f1-score   support
#
#            0       0.54      0.65      0.59      1019
#            1       0.22      0.15      0.18       478
#            2       0.23      0.24      0.23       472
#            3       0.31      0.23      0.27       546
#            4       0.28      0.22      0.25       503
#            5       0.27      0.35      0.30       593
#            6       0.21      0.15      0.17       475
#            7       0.48      0.57      0.52       914
#
#     accuracy                           0.37      5000
#    macro avg       0.32      0.32      0.31      5000
# weighted avg       0.36      0.37      0.36      5000

# %% [markdown]
# Испробовав различные варианты с TfIdfVectorizer приходим к выводу, что это не лучший способ обработки текстов отзывов, ведь даже сложные последовательные модели или стекинги не могут добиться лучшей точности при заметном дисбалансе классов. Каждая модель имеет хорошую точность только на низшей и высшей оценке, а лучше всех с этой задачей предсказания рейтинг справился VotingClassifier:

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler
import numpy as np

# Определяем модели с использованием GPU для CatBoost
catboost_model = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    eval_metric='MultiClass',
    task_type='GPU',  # Использование GPU
    silent=True
)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
lr_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Создаем pipeline для каждой модели
catboost_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('catboost', catboost_model)
])

rf_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('random_forest', rf_model)
])

lr_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('logistic_regression', lr_model)
])

# Определяем, сколько элементов в каждом классе
class_counts = train_df['rating'].value_counts()

# Устанавливаем целевое количество для классов с количеством меньше 5000
target_count = 5000
sampling_strategy = {label: target_count for label, count in class_counts.items() if count < target_count}

# Создаем oversampler с определенной стратегией
oversampler = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=42)

# Применение oversampling к обучающему набору
X_resampled, y_resampled = oversampler.fit_resample(train_df[['review']], train_df['rating'])

# Обучение ансамбля на увеличенном наборе данных
voting_clf.fit(X_resampled['review'], y_resampled)

# Предсказание на тестовом наборе
y_pred = voting_clf.predict(test_df['review'])

# Оценка производительности
print(classification_report(test_df['rating'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.74      0.64      5022
#            2       0.23      0.13      0.16      2302
#            3       0.28      0.18      0.22      2541
#            4       0.32      0.34      0.33      2635
#            7       0.30      0.30      0.30      2307
#            8       0.26      0.23      0.25      2850
#            9       0.24      0.14      0.17      2344
#           10       0.51      0.68      0.58      4999
#
#     accuracy                           0.42     25000
#    macro avg       0.34      0.34      0.33     25000
# weighted avg       0.38      0.42      0.39     25000

# %%
import joblib

# Сохранение модели голосующего классификатора
joblib.dump(voting_clf, 'voting_classifier_model.joblib')

# Сохранение TF-IDF векторизатора
# joblib.dump(tfidf_vectorizer, 'voting_tfidf_vectorizer.joblib')
